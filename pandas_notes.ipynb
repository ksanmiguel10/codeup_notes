# %%
import numpy as np             #pandas works with numpy; have to import both
import pandas as pd

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students, 
                   'math': math_grades, 
                   'english': english_grades, 
                   'reading': reading_grades})

print(df) #formatting within pandas library
# Out:
#        name  math  english  reading
# 0     Sally    66       61       65
# 1      Jane    71       90       89
# 2     Suzie    93       72       80
# 3     Billy    75       75       75
# 4       Ada    66       98       98
# 5      John    76       99       71
# 6    Thomas    98       63       75
# 7     Marie    89       83       82
# 8    Albert    84       64       84
# 9   Richard    70       64       97
# 10    Isaac    92       95       99
# 11     Alan    98       69       86

# %%
df # get a nicer table if df is the last thing in the cell; only part of jupyter notebooks
# Out:
#        name  math  english  reading
# 0     Sally    66       61       65
# 1      Jane    71       90       89
# 2     Suzie    93       72       80
# 3     Billy    75       75       75
# 4       Ada    66       98       98
# 5      John    76       99       71
# 6    Thomas    98       63       75
# 7     Marie    89       83       82
# 8    Albert    84       64       84
# 9   Richard    70       64       97
# 10    Isaac    92       95       99
# 11     Alan    98       69       86

# %%
1 + 2 #only shows the last thing in the cell
2 * 5
# Out:
# 10

# %%
df.dtypes
# Out:
# name       object
# math        int64
# english     int64
# reading     int64
# dtype: object

# %%
df.shape
# Out:
# (12, 4)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df.columns
# Out:
# Index(['name', 'math', 'english', 'reading'], dtype='object')

# %%
df.columns = ['student_name', 'math_grade', 'eng_grade', 'read_grade'] #renaming columns

# %%
df
# Out:
#    student_name  math_grade  eng_grade  read_grade
# 0         Sally          66         61          65
# 1          Jane          71         90          89
# 2         Suzie          93         72          80
# 3         Billy          75         75          75
# 4           Ada          66         98          98
# 5          John          76         99          71
# 6        Thomas          98         63          75
# 7         Marie          89         83          82
# 8        Albert          84         64          84
# 9       Richard          70         64          97
# 10        Isaac          92         95          99
# 11         Alan          98         69          86

# %%
uppercased_cols = []  #uppercase columns with a for loop
for col in df:
    uppercased_cols.append(col.upper())
    
df.columns = uppercased_cols

df
# Out:
#    STUDENT_NAME  MATH_GRADE  ENG_GRADE  READ_GRADE
# 0         Sally          66         61          65
# 1          Jane          71         90          89
# 2         Suzie          93         72          80
# 3         Billy          75         75          75
# 4           Ada          66         98          98
# 5          John          76         99          71
# 6        Thomas          98         63          75
# 7         Marie          89         83          82
# 8        Albert          84         64          84
# 9       Richard          70         64          97
# 10        Isaac          92         95          99
# 11         Alan          98         69          86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
# STUDENT_NAME    12 non-null object
# MATH_GRADE      12 non-null int64
# ENG_GRADE       12 non-null int64
# READ_GRADE      12 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 464.0+ bytes

# %%
#vertical slice; ONLY works with pandas df
df[['STUDENT_NAME', 'MATH_GRADE']] #LIST as an index
# Out:
#    STUDENT_NAME  MATH_GRADE
# 0         Sally          66
# 1          Jane          71
# 2         Suzie          93
# 3         Billy          75
# 4           Ada          66
# 5          John          76
# 6        Thomas          98
# 7         Marie          89
# 8        Albert          84
# 9       Richard          70
# 10        Isaac          92
# 11         Alan          98

# %%
df['STUDENT_NAME'] #STRING as an index; gives 'series' of data; single brackets
# Out:
# 0       Sally
# 1        Jane
# 2       Suzie
# 3       Billy
# 4         Ada
# 5        John
# 6      Thomas
# 7       Marie
# 8      Albert
# 9     Richard
# 10      Isaac
# 11       Alan
# Name: STUDENT_NAME, dtype: object

# %%
type(df['STUDENT_NAME']) #SINGLE brackets --> series
# Out:
# pandas.core.series.Series

# %%
type(df[['STUDENT_NAME']]) #DOUBLE brackets --> data frame
# Out:
# pandas.core.frame.DataFrame

# %%
df.MATH_GRADE[df.MATH_GRADE > 60] #index just what you want
# Out:
# 0     66
# 1     71
# 2     93
# 3     75
# 4     66
# 5     76
# 6     98
# 7     89
# 8     84
# 9     70
# 10    92
# 11    98
# Name: MATH_GRADE, dtype: int64

# %%
df[df.MATH_GRADE > 60] #whole table with just the index you want
# Out:
#    STUDENT_NAME  MATH_GRADE  ENG_GRADE  READ_GRADE
# 0         Sally          66         61          65
# 1          Jane          71         90          89
# 2         Suzie          93         72          80
# 3         Billy          75         75          75
# 4           Ada          66         98          98
# 5          John          76         99          71
# 6        Thomas          98         63          75
# 7         Marie          89         83          82
# 8        Albert          84         64          84
# 9       Richard          70         64          97
# 10        Isaac          92         95          99
# 11         Alan          98         69          86

# %%
df.iloc[4:8] #horizontal slices
# Out:
#   STUDENT_NAME  MATH_GRADE  ENG_GRADE  READ_GRADE
# 4          Ada          66         98          98
# 5         John          76         99          71
# 6       Thomas          98         63          75
# 7        Marie          89         83          82

# %%
df.head() #default is 5; can specify how many you want by putting number in ()
# Out:
#   STUDENT_NAME  MATH_GRADE  ENG_GRADE  READ_GRADE
# 0        Sally          66         61          65
# 1         Jane          71         90          89
# 2        Suzie          93         72          80
# 3        Billy          75         75          75
# 4          Ada          66         98          98

# %%
df.tail()
# Out:
#    STUDENT_NAME  MATH_GRADE  ENG_GRADE  READ_GRADE
# 7         Marie          89         83          82
# 8        Albert          84         64          84
# 9       Richard          70         64          97
# 10        Isaac          92         95          99
# 11         Alan          98         69          86

# %%
df.iloc[4:8, 1:3] #row slice, column slice
# Out:
#    MATH_GRADE  ENG_GRADE
# 4          66         98
# 5          76         99
# 6          98         63
# 7          89         83

# %%
df.sample() #random sample; can specify how many in ()
# Out:
#   STUDENT_NAME  MATH_GRADE  ENG_GRADE  READ_GRADE
# 1         Jane          71         90          89

# %%
df.rename(columns={'STUDENT_NAME': 'st_name'}) #rename column; does NOT modify original df; {'oldname': 'newname'}
# Out:
#     st_name  MATH_GRADE  ENG_GRADE  READ_GRADE
# 0     Sally          66         61          65
# 1      Jane          71         90          89
# 2     Suzie          93         72          80
# 3     Billy          75         75          75
# 4       Ada          66         98          98
# 5      John          76         99          71
# 6    Thomas          98         63          75
# 7     Marie          89         83          82
# 8    Albert          84         64          84
# 9   Richard          70         64          97
# 10    Isaac          92         95          99
# 11     Alan          98         69          86

# %%
#to change the underlying data frame (i.e. modify the df variable)
df.rename(columns={'MATH_GRADE': 'mathematics_grade'}, inplace=True)

# %%
df #original df column name changed becauese of inplace=True above ^^^
# Out:
#    STUDENT_NAME  mathematics_grade  ENG_GRADE  READ_GRADE
# 0         Sally                 66         61          65
# 1          Jane                 71         90          89
# 2         Suzie                 93         72          80
# 3         Billy                 75         75          75
# 4           Ada                 66         98          98
# 5          John                 76         99          71
# 6        Thomas                 98         63          75
# 7         Marie                 89         83          82
# 8        Albert                 84         64          84
# 9       Richard                 70         64          97
# 10        Isaac                 92         95          99
# 11         Alan                 98         69          86

# %%
avg_grade = (df.mathematics_grade + df.ENG_GRADE + df.READ_GRADE) / 3 #avg grade for each student

#creating a new column in the data frame; DOES change the underlying df
df['avg_grade'] = avg_grade

df
# Out:
#    STUDENT_NAME  mathematics_grade  ENG_GRADE  READ_GRADE  avg_grade
# 0         Sally                 66         61          65  64.000000
# 1          Jane                 71         90          89  83.333333
# 2         Suzie                 93         72          80  81.666667
# 3         Billy                 75         75          75  75.000000
# 4           Ada                 66         98          98  87.333333
# 5          John                 76         99          71  82.000000
# 6        Thomas                 98         63          75  78.666667
# 7         Marie                 89         83          82  84.666667
# 8        Albert                 84         64          84  77.333333
# 9       Richard                 70         64          97  77.000000
# 10        Isaac                 92         95          99  95.333333
# 11         Alan                 98         69          86  84.333333

# %%
df.assign(curved_math=df.mathematics_grade + 10) #creating another column; DOES NOT modify underlying df
# Out:
#    STUDENT_NAME  mathematics_grade  ENG_GRADE  READ_GRADE  avg_grade  \
# 0         Sally                 66         61          65  64.000000
# 1          Jane                 71         90          89  83.333333
# 2         Suzie                 93         72          80  81.666667
# 3         Billy                 75         75          75  75.000000
# 4           Ada                 66         98          98  87.333333
# 5          John                 76         99          71  82.000000
# 6        Thomas                 98         63          75  78.666667
# 7         Marie                 89         83          82  84.666667
# 8        Albert                 84         64          84  77.333333
# 9       Richard                 70         64          97  77.000000
# 10        Isaac                 92         95          99  95.333333
# 11         Alan                 98         69          86  84.333333
#
#     curved_math
# 0            76
# 1            81
# 2           103
# ...

# %%
#apply function to every value in the series using '.apply()'

def describe_grade(number_grade: int) -> str:
    if number_grade > 90:
        return 'Great!'
    elif number_grade > 70:
        return 'Ok'
    else:
        return 'Uh oh..'
    
df.mathematics_grade.apply(describe_grade)
# Out:
# 0     Uh oh..
# 1          Ok
# 2      Great!
# 3          Ok
# 4     Uh oh..
# 5          Ok
# 6      Great!
# 7          Ok
# 8          Ok
# 9     Uh oh..
# 10     Great!
# 11     Great!
# Name: mathematics_grade, dtype: object

# %%
def curve_grade(number_grade):
    new_grade = number_grade + 10
    if new_grade > 100:
        return 100
    else: return new_grade
    
df['curved_math_grade'] = df.mathematics_grade.apply(curve_grade) 
#passing function through .apply and mapping onto new series
#'higher order function'- accepts a fn as an argument or returns a fn

# %%
df[['STUDENT_NAME', 'curved_math_grade', 'mathematics_grade']]
# Out:
#    STUDENT_NAME  curved_math_grade  mathematics_grade
# 0         Sally                 76                 66
# 1          Jane                 81                 71
# 2         Suzie                100                 93
# 3         Billy                 85                 75
# 4           Ada                 76                 66
# 5          John                 86                 76
# 6        Thomas                100                 98
# 7         Marie                 99                 89
# 8        Albert                 94                 84
# 9       Richard                 80                 70
# 10        Isaac                100                 92
# 11         Alan                100                 98

# %%
df.READ_GRADE.apply(lambda grade: 'passing' if grade >= 70 else 'failing') #LAMBDA function applies to every element
# Out:
# 0     failing
# 1     passing
# 2     passing
# 3     passing
# 4     passing
# 5     passing
# 6     passing
# 7     passing
# 8     passing
# 9     passing
# 10    passing
# 11    passing
# Name: READ_GRADE, dtype: object

# %%
df.READ_GRADE > 70 #produces array of boolean values
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# Name: READ_GRADE, dtype: bool

# %%
(df.READ_GRADE > 70).all() #will return True if ALL are True, if not, will return False
# Out:
# False

# %%
(df.READ_GRADE > 70).any() #will return True if ANY are True, if not, will return False
# Out:
# True

# %%
df.ENG_GRADE.max()
# Out:
# 99

# %%
df.STUDENT_NAME.str.upper() 
#can apply string operations to all values in series instead of using for loops
#string operations do NOT change underlying df
# Out:
# 0       SALLY
# 1        JANE
# 2       SUZIE
# 3       BILLY
# 4         ADA
# 5        JOHN
# 6      THOMAS
# 7       MARIE
# 8      ALBERT
# 9     RICHARD
# 10      ISAAC
# 11       ALAN
# Name: STUDENT_NAME, dtype: object

# %%
df.STUDENT_NAME = df.STUDENT_NAME.str.replace('.$', '!', regex=True)

# %%
df
# Out:
#    STUDENT_NAME  mathematics_grade  ENG_GRADE  READ_GRADE  avg_grade  \
# 0         Sall!                 66         61          65  64.000000
# 1          Jan!                 71         90          89  83.333333
# 2         Suzi!                 93         72          80  81.666667
# 3         Bill!                 75         75          75  75.000000
# 4           Ad!                 66         98          98  87.333333
# 5          Joh!                 76         99          71  82.000000
# 6        Thoma!                 98         63          75  78.666667
# 7         Mari!                 89         83          82  84.666667
# 8        Alber!                 84         64          84  77.333333
# 9       Richar!                 70         64          97  77.000000
# 10        Isaa!                 92         95          99  95.333333
# 11         Ala!                 98         69          86  84.333333
#
#     curved_math_grade
# 0                  76
# 1                  81
# ...

# %% [markdown]
# # Lecture Part 2

# %%
import pandas as pd

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

df.sort_values(by='math', ascending=False)
# Out:
#        name  math  english  reading
# 10    Isaac    99       75       87
# 1      Jane    97       86       60
# 5      John    93       80       64
# 8    Albert    91       69       73
# 6    Thomas    88       75       70
# 3     Billy    84       60       76
# 0     Sally    82       64       63
# 4       Ada    72       63       95
# 9   Richard    70       73       90
# 2     Suzie    65       95       65
# 11     Alan    65       71       89
# 7     Marie    61       99       93

# %%
n_students = df.shape[0]

df['group'] = np.random.choice(['A', 'B', 'C'], n_students)
df
# Out:
#        name  math  english  reading group
# 0     Sally    82       64       63     B
# 1      Jane    97       86       60     C
# 2     Suzie    65       95       65     B
# 3     Billy    84       60       76     A
# 4       Ada    72       63       95     B
# 5      John    93       80       64     C
# 6    Thomas    88       75       70     A
# 7     Marie    61       99       93     A
# 8    Albert    91       69       73     A
# 9   Richard    70       73       90     A
# 10    Isaac    99       75       87     C
# 11     Alan    65       71       89     C

# %%
#SELECT min('math') FROM students GROUP BY group;
df.groupby('group', as_index=False)['math'].min()
# Out:
#   group  math
# 0     A    61
# 1     B    65
# 2     C    65

# %%
df[['group', 'reading']].groupby('group').agg([np.mean, 'min', 'max'])
# Out:
#          reading
#             mean min max
# group
# A      80.400000  70  93
# B      74.333333  63  95
# C      75.000000  60  89

# %%
df[['group', 'reading']].groupby('group').count()
# Out:
#        reading
# group
# A            5
# B            3
# C            4

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

df.math.plot() #line graph
df.math.hist() #histogram
df.math.box() #box-plot

# %%
df.plot.scatter(x='math', y='reading', c='red')

# %%
df.plot.box()

# %%
df[['math', 'group']].groupby('group').mean().plot.bar() #series

# %% [markdown]
# # Lecture part 3

# %%
import numpy as np             #pandas works with numpy; have to import both
import pandas as pd

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students, 
                   'math': math_grades, 
                   'english': english_grades, 
                   'reading': reading_grades})

print(df) #formatting within pandas library
# Out:
#        name  math  english  reading
# 0     Sally    82       64       63
# 1      Jane    97       86       60
# 2     Suzie    65       95       65
# 3     Billy    84       60       76
# 4       Ada    72       63       95
# 5      John    93       80       64
# 6    Thomas    88       75       70
# 7     Marie    61       99       93
# 8    Albert    91       69       73
# 9   Richard    70       73       90
# 10    Isaac    99       75       87
# 11     Alan    65       71       89

# %%
df.plot.box()

# %%
#MELT

melted_df = pd.melt(df[['name', 'math', 'english', 'reading']],
                   id_vars = ['name'], #unique id; not changing
                   var_name = 'subject', #metrics to plot
                   value_name = 'grade')

melted_df.sample(10)
# Out:
#        name  subject  grade
# 19    Marie  english     99
# 34    Isaac  reading     87
# 11     Alan     math     65
# 8    Albert     math     91
# 9   Richard     math     70
# 2     Suzie     math     65
# 20   Albert  english     69
# 10    Isaac     math     99
# 1      Jane     math     97
# 17     John  english     80

# %%
#sns.set(style='whitegrid', palette='muted')
plt.figure(figsize=(4,4))

#plt.subplot(111)
plt.scatter(melted_df.subject, melted_df.grade)
plt.title('Grades')

plt.show()

# %%
# reading in csv

data = '''
apple;3
banana;4
cantelope;16
dragonfruit;1
elderberry;2
'''.strip()

with open('fruits.csv', 'w') as f:
    f.write(data)

# %%
df = pd.read_csv('fruits.csv', header=None)

# %%
df.columns = ['fruits']

# %%
pd.read_csv('fruits.csv', header=None, sep=';')
# Out:
#              0   1
# 0        apple   3
# 1       banana   4
# 2    cantelope  16
# 3  dragonfruit   1
# 4   elderberry   2

# %%
#reading json

data = '''
[
  {"name": "apple", "quantity": 3},
  {"name": "banana", "quantity": 4},
  {"name": "cantelope", "quantity": 16},
  {"name": "dragonfruit", "quantity": 1},
  {"name": "elderberry", "quantity": 2}
]
'''.strip()

with open('fruits.json', 'w') as f:
    f.write(data)

# %%
pd.read_json('fruits.json')
# Out:
#           name  quantity
# 0        apple         3
# 1       banana         4
# 2    cantelope        16
# 3  dragonfruit         1
# 4   elderberry         2

# %%
# cleanup the test files we created
from os import remove as rm

for file in ('fruits.csv', 'fruits.json'):
    try:
        rm(file)
    except FileNotFoundError:
        pass

# %%
path = 'data/'

pd.read_csv(path + 'iris.csv').head()
